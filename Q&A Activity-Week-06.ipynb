# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trade_data=pd.read_csv('Dataset_w6.xlsx - Data.csv')

# %%
trade_data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# ...

# %% [markdown]
# ## 1. Find out how many countries are there in the dataset.

# %% [markdown]
# ### Count the no: of  countries

# %%
# counting the number of countries using nunique(),so NaN values are not included in the count.
trade_data.country.nunique()
# Out:
# 196

# %%
#setting the max_row display option
pd.options.display.max_rows = 1000

# %%
#Names of countries and GDP per capita (current US$) of each country
trade_data[['country','GDP per capita (current US$)']]
# Out:
#                                        country  GDP per capita (current US$)
# 0                                  Afghanistan                         623.2
# 1                                      Albania                        3984.2
# 2                                      Algeria                        4154.1
# 3                                       Angola                        4714.1
# 4                          Antigua and Barbuda                       14764.5
# 5                                    Argentina                       14564.5
# 6                                      Armenia                        3489.1
# 7                                    Australia                       51352.2
# 8                                      Austria                       44117.7
# 9                                   Azerbaijan                        5438.7
# 10                                     Bahamas                       22817.2
# ...

# %% [markdown]
# ## 2. Examine the data by using visualizations.

# %%
#Distribution of GDP per capita
trade_data['GDP per capita (current US$)'].plot(kind='kde', figsize=(10,6), title='Distribution of GDP per capita (current US$)')
# Out:
# <AxesSubplot:title={'center':'Distribution of GDP per capita (current US$)'}, ylabel='Density'>

# %%
#Bar plot of Top 15countries based on International trade
tdata=trade_data.sort_values('International trade: Imports (million US$)',ascending=False).head(15)
tdata.plot.barh(x='country',y='International trade: Imports (million US$)')
# Out:
# <AxesSubplot:ylabel='country'>

# %%
#Countplot of Region
plt.figure(figsize=(17,6))
sns.countplot(tdata['Region'], palette = 'Blues')
plt.title('Comparison of Region', fontweight = 30, fontsize = 20)
plt.xlabel('Region')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\TECHNOSOFT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Barplot of Top 15countries based on popoulation
pop_data = trade_data.sort_values('Population in thousands (2017)',ascending=False).head(15)
pop_data.plot.barh(x='country',y='Population in thousands (2017)', figsize=(16,17))
# Out:
# <AxesSubplot:ylabel='country'>

# %%
#Barplot of Top 15 countries based on surface area
area_data = trade_data.sort_values('Surface area (km2)',ascending=False).head(15)
plt.figure(figsize=(17,6))
plt.xticks(rotation=90)
sns.barplot(x='country', y='Surface area (km2)',data=area_data)
plt.title('Surface area')
# Out:
# Text(0.5, 1.0, 'Surface area')

# %% [markdown]
# ### 3. Find out how many countries with respect to the region are available in the dataset

# %%
#countries with respect to the region 
trade_data.groupby(['Region', 'country']).size()
# Out:
# Region             country
# Caribbean          Antigua and Barbuda                          1
#                    Bahamas                                      1
#                    Barbados                                     1
#                    British Virgin Islands                       1
#                    Cayman Islands                               1
#                    Cuba                                         1
#                    Dominica                                     1
#                    Dominican Republic                           1
#                    Grenada                                      1
#                    Haiti                                        1
#                    Jamaica                                      1
#                    Montserrat                                   1
#                    Saint Kitts and Nevis                        1
#                    Saint Lucia                                  1
# ...

# %%
#No:of countries for each region
trade_data.groupby('Region')['country'].count().reset_index()
# Out:
#                Region  country
# 0           Caribbean       16
# 1      CentralAmerica        8
# 2         CentralAsia        5
# 3       EasternAfrica       17
# 4         EasternAsia        7
# 5       EasternEurope       10
# 6           Melanesia        5
# 7          Micronesia        4
# 8        MiddleAfrica        9
# 9      NorthernAfrica        5
# 10    NorthernAmerica        4
# 11     NorthernEurope       10
# 12            Oceania        2
# 13          Polynesia        5
# 14  South-easternAsia       11
# 15       SouthAmerica       12
# 16     SouthernAfrica        5
# 17       SouthernAsia        9
# 18     SouthernEurope       12
# 19      WesternAfrica       15
# 20        WesternAsia       18
# 21      WesternEurope        7

# %% [markdown]
# ### 4. On average which region has the highest
# a. GDP per capita (current US$)
# b. International trade: Imports (million US$)

# %%
#Based on GDP
trade_data.groupby("Region")["GDP per capita (current US$)"].mean().sort_values(ascending=False)
# Out:
# Region
# NorthernAmerica      57659.000000
# WesternEurope        55387.128571
# Oceania              44823.250000
# NorthernEurope       42098.220000
# EasternAsia          27967.614286
# WesternAsia          17013.938889
# Caribbean            15135.562500
# SouthernEurope       14462.741667
# South-easternAsia    10299.027273
# EasternEurope         9292.490000
# Melanesia             9261.960000
# Polynesia             8686.520000
# SouthAmerica          8499.775000
# CentralAmerica        6348.137500
# Micronesia            5008.300000
# CentralAsia           4329.880000
# SouthernAfrica        4191.900000
# NorthernAfrica        3934.960000
# MiddleAfrica          3928.833333
# SouthernAsia          2968.400000
# EasternAfrica         2088.852941
# WesternAfrica         1013.140000
# Name: GDP per capita (current US$), dtype: float64

# %%
#Based on International trade
trade_data.groupby("Region")["International trade: Imports (million US$)"].mean().sort_values(ascending=False)
# Out:
# Region
# NorthernAmerica      663552.250000
# EasternAsia          451995.000000
# WesternEurope        407498.428571
# NorthernEurope       113407.200000
# Oceania              112914.500000
# South-easternAsia     98324.636364
# EasternEurope         85243.900000
# SouthernEurope        76666.666667
# SouthernAsia          58199.333333
# CentralAmerica        57031.500000
# WesternAsia           46025.555556
# NorthernAfrica        35034.400000
# SouthAmerica          32885.666667
# SouthernAfrica        18005.600000
# CentralAsia           12063.400000
# WesternAfrica          4898.333333
# EasternAfrica          4726.176471
# MiddleAfrica           4381.222222
# Caribbean              3057.312500
# Melanesia              2896.400000
# Polynesia               432.000000
# Micronesia               99.000000
# Name: International trade: Imports (million US$), dtype: float64

# %% [markdown]
# ### 5. Find out which region has more consistent with respect to GDP percapita (current US$)

# %%
#Region has more consistent with GDP 
data=trade_data[['GDP per capita (current US$)','Region']].groupby("Region").std().sort_values(by=['GDP per capita (current US$)'],inplace=False)
data
# Out:
#                    GDP per capita (current US$)
# Region
# WesternAfrica                        815.095399
# NorthernAfrica                       974.706575
# SouthernAfrica                      2177.551120
# SouthernAsia                        2855.708179
# EasternAfrica                       3716.131770
# CentralAsia                         4152.215490
# CentralAmerica                      4180.440883
# SouthAmerica                        4273.707394
# Micronesia                          4820.669694
# MiddleAfrica                        5274.846281
# EasternEurope                       5415.488739
# Polynesia                           6956.250286
# Oceania                             9233.329638
# SouthernEurope                      9541.703216
# Melanesia                          13855.842686
# Caribbean                          14579.371326
# South-easternAsia                  16311.810656
# WesternAsia                        18812.151459
# ...

# %% [markdown]
# SUBMITTED BY:GROUP-8(DSA-B3)
